# %%
import dlc_bci as bci
import numpy as np
import matplotlib.pyplot as plt
import torch
import random
random.seed(452)
import time
from torch.autograd import Variable
from torch import nn, optim
from torch.nn import functional as F

# %% [markdown]
# ## Import data

# %%
big_data = True 
train_input, train_target = bci.load(root ="./data_bci", one_khz=big_data)
print(str(type(train_input)), train_input.size())
print(str(type(train_target)), train_target.size())
test_input, test_target = bci.load(root ="./data_bci", train = False, one_khz=False)
print(str(type(test_input)), test_input.size())
print(str(type(test_target)), test_target.size())
# Out:
# <class 'torch.Tensor'> torch.Size([316, 28, 500])
# <class 'torch.Tensor'> torch.Size([316])
# <class 'torch.Tensor'> torch.Size([100, 28, 50])
# <class 'torch.Tensor'> torch.Size([100])

# %% [markdown]
# ## visualize data

# %%
n_train_samples = train_target.size()[0]
print('Number of training samples = {}'.format(n_train_samples))
n_test_samples = test_target.size()[0]
print('Number of testing samples = {}'.format(n_test_samples))
n_channels = train_input.size()[1]
print('Number of channels = {}'.format(n_channels))
n_readings = train_input.size()[2]
print('Number of readings per channel = {}'.format(n_readings))

freq = 2*n_readings

tt = np.arange(0,0.5,1/freq)

for i in range(n_channels):
    plt.plot(tt,train_input[0,i,:].numpy())
    
plt.show()
# Out:
# Number of training samples = 316
# Number of testing samples = 100
# Number of channels = 28
# Number of readings per channel = 500

# %%
plt.plot(tt,train_input[10:27,8,:].numpy().transpose())
plt.show()

# %% [markdown]
# ## Augment Data using different sampling shift

# %%
down_sampling = True

if(down_sampling == True):
    
    big_data_set = torch.Tensor(0,28,50)
    big_target = torch.Tensor(0)
    for i in range(10):
        shifted_data = train_input[:,:,i::10]
        big_data_set = torch.cat((big_data_set,shifted_data),0)
        big_target = torch.cat((big_target,train_target.type(torch.FloatTensor)),0)
    
train_input = big_data_set
train_target = big_target.type(torch.LongTensor)
print(big_data_set.shape)
print(big_target.shape)
# Out:
# torch.Size([3160, 28, 50])
# torch.Size([3160])

# %% [markdown]
# ## Normalize augmented data

# %%
train_input = (train_input - torch.mean(train_input,0,keepdim=True))/torch.std(train_input,0,True)
test_input = (test_input - torch.mean(test_input,0,keepdim=True))/torch.std(test_input,0,True)

# %% [markdown]
# ## Define Network

# %%
class MyNet(nn.Module):
    def __init__(self, big_data):
        super(MyNet, self).__init__()
        
        # Layer 1
        self.conv1a = nn.Conv2d(1, 8, (1, 5), dilation=2) # Apply convolution on each channels
        self.batchnorm1a = nn.BatchNorm2d(8, False) # Normalize

        self.conv1b = nn.Conv2d(8, 16, (1, 5)) # Apply convolution on each channels
        self.batchnorm1b = nn.BatchNorm2d(16, False) # Normalize
        # Layer 2
        self.conv2 = nn.Conv2d(16,32,(28, 1)) # Apply one convolution on each timestamp
        self.batchnorm2 = nn.BatchNorm2d(32, False) # Normalize
             
        # Fully Connected Layers
        self.fc1 = nn.Linear(1216,256)
        self.fc2 = nn.Linear(256,128)
        self.fc3 = nn.Linear(128,64)
        self.fc4 = nn.Linear(64,1)
    
    def forward(self, x):

        #print("input shape : {}".format(x.shape))
        x = self.conv1a(x)
        #print("Shape after self.conv1a(x) : {}".format(x.shape))
        x = self.batchnorm1a(x)
        #print("Shape after self.batchnorm1a(x) : {}".format(x.shape))
        x = self.conv1b(x)
        #print("Shape after self.conv1b(x) : {}".format(x.shape))
        x = self.batchnorm1b(x)
        #print("Shape after self.batchnorm1b(x) : {}".format(x.shape))
        x = self.conv2(x)
        x = F.elu(self.batchnorm2(x))
        #print("Shape after secondConvolution : {}".format(x.shape))
        x = F.dropout2d(x,0.5)
        s = x.shape
        a = s[1]*s[2]*s[3] #s[1]*s[2]*s[3] = 32*1*42
        x = x.view(-1,a) 
        #print("Flatten shape for FC : {}".format(x.shape))
        x = F.elu(self.fc1(x))
        x = F.elu(self.fc2(x))
        x = F.dropout(x,0.5)
        x = F.elu(self.fc3(x))
        x = F.sigmoid(self.fc4(x))
        #print("Output format : {}".format(x.shape))
        
        return x

# %%
class MyNet2(nn.Module):
    def __init__(self, big_data):
        super(MyNet2, self).__init__()
        
        self.fc1 = nn.Linear(28*50,128)
        self.fc2 = nn.Linear(128,1)
        
    def forward(self,x):
        
        #print("input shape : {}".format(x.shape))
        x = x.view(-1,28*50)
        #print("Flatten shape for FC : {}".format(x.shape))
        x = F.dropout(x,0.5)
        x = F.relu(self.fc1(x))
        #print(self.fc2(x))
        x = F.sigmoid(self.fc2(x))
        
        return x

# %%
class MyNet3(nn.Module):
    def __init__(self, big_data):
        super(MyNet3, self).__init__()
        
        self.conv1 = nn.Conv2d(1, 4, (1, 5), dilation=2)
        self.batchnorm1 = nn.BatchNorm2d(4,False)
        self.conv2 = nn.Conv2d(4,4,(28,1))
        self.batchnorm2 = nn.BatchNorm2d(4, False) # Normalize
        self.fc1 = nn.Linear(4*42,64)    
        self.fc2 = nn.Linear(64,1)
        
    def forward(self,x):
        
        #print("input shape : {}".format(x.shape))
        x = self.conv1(x)
        #print("Shape after self.conv1(x) : {}".format(x.shape))
        x = self.batchnorm1(x)
        #print("Shape after self.batchnorm1(x) : {}".format(x.shape))
        x = self.conv2(x)
        #print("Shape after self.conv2(x) : {}".format(x.shape))
        x = self.batchnorm2(x)
        #print("Shape after self.batchnorm2(x) : {}".format(x.shape))
        x = x.view(-1,4*42)
        #print("Flatten shape for FC : {}".format(x.shape))
        x = F.relu(self.fc1(x))
        x = F.dropout(x,0.6)
        #print("after fc1 : {}".format(x.shape))      
        x = F.sigmoid(self.fc2(x))
        
        return x

# %% [markdown]
# ## Train

# %%
def Validation(Y_pred, Y_true):
    return BCE(Y_true,Y_pred)

def N_true(Y_pred, Y_true):
    return torch.sum(torch.round(Y_pred).squeeze()==Y_true.float()).type(torch.FloatTensor)/Y_true.shape[0]
     
def BCE(Y_true,Y_pred):
    
    l = Variable(torch.Tensor(len(Y_true)))
    for i in range(len(Y_true)):
        if(Y_true[i]==1).data.numpy():
            l[i] = - Y_pred[i].log()
        else:
            l[i] = - (1-Y_pred[i]).log() 
        
    return torch.mean(l)

# %%
big_data = False
net = MyNet3(big_data)
#optimizer = optim.Adam(net.parameters(), lr=0.00005)
optimizer = optim.SGD(net.parameters(), lr=0.001, momentum=0.4)

batch_size = 15
n_max_epochs = 100
n_validation_samples = 160

train_err = []
val_err = []
val_truth = []
train_truth = []

#Prepare validation data
#print(len(train_input))
val_idx = random.sample(range(n_train_samples), int(n_validation_samples/10)) # pick 16 high resolution samples
val_list_idx = []
for k in range(10):
    for i in range(len(val_idx)):
        val_list_idx.append(val_idx[i]+316*k) #generate validation set from same 16 High resolution samples
train_idx = np.delete(np.arange(len(train_input)),val_list_idx)
#print(len(train_idx))
val_X = Variable(torch.unsqueeze(train_input[torch.LongTensor(val_list_idx)],1),requires_grad=True)
#print(len(val_X))
val_Y = Variable((train_target[torch.LongTensor(val_list_idx)]))

#Prepare training data
train_X = Variable(torch.unsqueeze(train_input[torch.LongTensor(train_idx)],1))
train_Y = Variable(train_target[torch.LongTensor(train_idx)])

for epoch in range(n_max_epochs):  # loop over the dataset multiple times
    print("\nEpoch ", epoch)
    
    net.train()
    
    train_loss = 0.0
    epoch_true = 0.0
    #print(len(train_X))
    
    for b in range(0, len(train_X), batch_size):   #Train batch by batch
    
        output = net(train_X.narrow(0, b, batch_size))
        loss = BCE(train_Y.narrow(0, b, batch_size),output.squeeze())
        #print(loss)
        net.zero_grad()
        loss.backward()
        optimizer.step()
        #scheduler.step(loss)
        train_loss = (train_loss + loss.data)/2
        batch_true = N_true(output, train_Y.narrow(0, b, batch_size))
        epoch_true = (epoch_true + batch_true)
        
    net.eval()  
    
    
    val_pred = net(val_X)
    train_err.append(train_loss) #add train loss
    val_err.append(Validation(val_pred,val_Y).data) #add validation loss
    val_truth.append(N_true(val_pred,val_Y)) #add validation accuracy
    print("classification accuracy on validation set: {}".format(val_truth[epoch].data.numpy()))
    train_truth.append(epoch_true/(len(train_input)/batch_size)) #add train accuracy
    print("classification accuracy on training set: {}".format(train_truth[epoch].data.numpy()))
    
    test_pred = net(Variable(torch.unsqueeze(test_input,1)))
#print("Binary Cross Entropy loss for test set: {}".format(BCE(Variable(test_target),test_pred)))
    print("classification accuracy on test set: {}%".format((N_true(net(Variable(torch.unsqueeze(test_input,1))),Variable(test_target)))*100))

    if(abs(train_loss-val_err[epoch])>0.3): 
        '''
        Early Stopping condition if error difference between train and validation too big.
        Train error reduces & Validation error increases -> overfitting'''
        #break
    
plt.plot(range(epoch+1),val_err,range(epoch+1),train_err)
plt.legend(['validation error', 'training error'])
plt.show()
# Out:
# Epoch  0
# classification accuracy on validation set: 0.4124999940395355
# classification accuracy on training set: 0.4819619655609131
# classification accuracy on test set: 55.0%
#
# Epoch  1
# classification accuracy on validation set: 0.4312500059604645
# classification accuracy on training set: 0.5066454410552979
# classification accuracy on test set: 51.0%
#
# Epoch  2
# classification accuracy on validation set: 0.4375
# classification accuracy on training set: 0.5443036556243896
# classification accuracy on test set: 51.0%
#
# Epoch  3
# classification accuracy on validation set: 0.4625000059604645
# classification accuracy on training set: 0.5677211284637451
# classification accuracy on test set: 50.0%
#
# Epoch  4
# classification accuracy on validation set: 0.4749999940395355
# classification accuracy on training set: 0.5908222794532776
# classification accuracy on test set: 50.0%
#
# Epoch  5
# classification accuracy on validation set: 0.4625000059604645
# classification accuracy on training set: 0.6063284873962402
# classification accuracy on test set: 49.0%
#
# Epoch  6
# classification accuracy on validation set: 0.48750001192092896
# classification accuracy on training set: 0.6142399311065674
# classification accuracy on test set: 47.0%
#
# Epoch  7
# classification accuracy on validation set: 0.48750001192092896
# classification accuracy on training set: 0.6259489059448242
# classification accuracy on test set: 47.0%
#
# Epoch  8
# classification accuracy on validation set: 0.48750001192092896
# classification accuracy on training set: 0.6306959986686707
# classification accuracy on test set: 49.0%
#
# Epoch  9
# classification accuracy on validation set: 0.4749999940395355
# classification accuracy on training set: 0.6386073231697083
# classification accuracy on test set: 50.0%
#
# Epoch  10
# classification accuracy on validation set: 0.4749999940395355
# classification accuracy on training set: 0.6481010913848877
# classification accuracy on test set: 50.0%
#
# Epoch  11
# classification accuracy on validation set: 0.48750001192092896
# classification accuracy on training set: 0.6547465920448303
# classification accuracy on test set: 52.999996185302734%
#
# Epoch  12
# classification accuracy on validation set: 0.4937500059604645
# classification accuracy on training set: 0.6623416543006897
# classification accuracy on test set: 52.0%
#
# Epoch  13
# classification accuracy on validation set: 0.4749999940395355
# classification accuracy on training set: 0.672152042388916
# classification accuracy on test set: 56.0%
#
# Epoch  14
# classification accuracy on validation set: 0.4937500059604645
# classification accuracy on training set: 0.6829115748405457
# classification accuracy on test set: 56.0%
#
# Epoch  15
# classification accuracy on validation set: 0.48124998807907104
# classification accuracy on training set: 0.6930380463600159
# classification accuracy on test set: 60.000003814697266%
#
# Epoch  16
# classification accuracy on validation set: 0.5687500238418579
# classification accuracy on training set: 0.7053799629211426
# classification accuracy on test set: 65.0%
#
# Epoch  17
# classification accuracy on validation set: 0.625
# classification accuracy on training set: 0.730063796043396
# classification accuracy on test set: 66.0%
#
# Epoch  18
# classification accuracy on validation set: 0.668749988079071
# classification accuracy on training set: 0.7455704212188721
# classification accuracy on test set: 73.0%
#
# Epoch  19
# classification accuracy on validation set: 0.6625000238418579
# classification accuracy on training set: 0.7601273655891418
# classification accuracy on test set: 75.0%
#
# Epoch  20
# classification accuracy on validation set: 0.6187499761581421
# classification accuracy on training set: 0.7765830755233765
# classification accuracy on test set: 77.0%
#
# Epoch  21
# classification accuracy on validation set: 0.637499988079071
# classification accuracy on training set: 0.7876589894294739
# classification accuracy on test set: 77.0%
#
# Epoch  22
# classification accuracy on validation set: 0.6499999761581421
# classification accuracy on training set: 0.7990512847900391
# classification accuracy on test set: 80.0%
#
# Epoch  23
# classification accuracy on validation set: 0.731249988079071
# classification accuracy on training set: 0.8075955510139465
# classification accuracy on test set: 81.0%
#
# Epoch  24
# classification accuracy on validation set: 0.75
# classification accuracy on training set: 0.8132917284965515
# classification accuracy on test set: 80.0%
#
# Epoch  25
# classification accuracy on validation set: 0.762499988079071
# classification accuracy on training set: 0.8183550834655762
# classification accuracy on test set: 79.0%
#
# Epoch  26
# classification accuracy on validation set: 0.7562500238418579
# classification accuracy on training set: 0.827215850353241
# classification accuracy on test set: 79.0%
#
# Epoch  27
# classification accuracy on validation set: 0.75
# classification accuracy on training set: 0.8395575881004333
# classification accuracy on test set: 81.0%
#
# Epoch  28
# classification accuracy on validation set: 0.75
# classification accuracy on training set: 0.8481018543243408
# classification accuracy on test set: 81.0%
#
# Epoch  29
# classification accuracy on validation set: 0.7562500238418579
# classification accuracy on training set: 0.8598108291625977
# classification accuracy on test set: 81.0%
#
# Epoch  30
# classification accuracy on validation set: 0.762499988079071
# classification accuracy on training set: 0.8667728304862976
# classification accuracy on test set: 82.0%
#
# Epoch  31
# classification accuracy on validation set: 0.762499988079071
# classification accuracy on training set: 0.8708867430686951
# classification accuracy on test set: 82.0%
#
# Epoch  32
# classification accuracy on validation set: 0.7749999761581421
# classification accuracy on training set: 0.877848744392395
# classification accuracy on test set: 82.0%
#
# Epoch  33
# classification accuracy on validation set: 0.7749999761581421
# classification accuracy on training set: 0.8803803324699402
# classification accuracy on test set: 81.0%
#
# Epoch  34
# classification accuracy on validation set: 0.7749999761581421
# classification accuracy on training set: 0.8857601284980774
# classification accuracy on test set: 81.0%
#
# Epoch  35
# classification accuracy on validation set: 0.793749988079071
# classification accuracy on training set: 0.8895574808120728
# classification accuracy on test set: 82.0%
#
# Epoch  36
# classification accuracy on validation set: 0.793749988079071
# classification accuracy on training set: 0.8946207761764526
# classification accuracy on test set: 82.0%
#
# Epoch  37
# classification accuracy on validation set: 0.793749988079071
# classification accuracy on training set: 0.8968359231948853
# classification accuracy on test set: 81.0%
#
# Epoch  38
# classification accuracy on validation set: 0.793749988079071
# classification accuracy on training set: 0.9012662172317505
# classification accuracy on test set: 81.0%
#
# Epoch  39
# classification accuracy on validation set: 0.793749988079071
# classification accuracy on training set: 0.9053802490234375
# classification accuracy on test set: 81.0%
#
# Epoch  40
# classification accuracy on validation set: 0.8062499761581421
# classification accuracy on training set: 0.9085447788238525
# classification accuracy on test set: 81.0%
#
# Epoch  41
# classification accuracy on validation set: 0.8062499761581421
# classification accuracy on training set: 0.9110763669013977
# classification accuracy on test set: 80.0%
#
# Epoch  42
# classification accuracy on validation set: 0.8062499761581421
# classification accuracy on training set: 0.9139243960380554
# classification accuracy on test set: 79.0%
#
# Epoch  43
# classification accuracy on validation set: 0.8125
# classification accuracy on training set: 0.9183547496795654
# classification accuracy on test set: 79.0%
#
# Epoch  44
# classification accuracy on validation set: 0.8125
# classification accuracy on training set: 0.9212028384208679
# classification accuracy on test set: 78.0%
#
# Epoch  45
# classification accuracy on validation set: 0.8125
# classification accuracy on training set: 0.9243673086166382
# classification accuracy on test set: 79.0%
#
# Epoch  46
# classification accuracy on validation set: 0.8125
# classification accuracy on training set: 0.9259495735168457
# classification accuracy on test set: 79.0%
#
# Epoch  47
# classification accuracy on validation set: 0.8125
# classification accuracy on training set: 0.927531898021698
# classification accuracy on test set: 79.0%
#
# Epoch  48
# classification accuracy on validation set: 0.8125
# classification accuracy on training set: 0.9287976622581482
# classification accuracy on test set: 78.0%
#
# Epoch  49
# classification accuracy on validation set: 0.8062499761581421
# classification accuracy on training set: 0.9303799271583557
# classification accuracy on test set: 77.0%
#
# Epoch  50
# classification accuracy on validation set: 0.8125
# classification accuracy on training set: 0.9319621920585632
# classification accuracy on test set: 78.0%
#
# Epoch  51
# classification accuracy on validation set: 0.8125
# classification accuracy on training set: 0.9325950741767883
# classification accuracy on test set: 78.0%
#
# Epoch  52
# classification accuracy on validation set: 0.8125
# classification accuracy on training set: 0.9344937801361084
# classification accuracy on test set: 78.0%
#
# Epoch  53
# classification accuracy on validation set: 0.8062499761581421
# classification accuracy on training set: 0.9360760450363159
# classification accuracy on test set: 78.0%
#
# Epoch  54
# classification accuracy on validation set: 0.8062499761581421
# classification accuracy on training set: 0.9373419284820557
# classification accuracy on test set: 78.0%
#
# Epoch  55
# classification accuracy on validation set: 0.8062499761581421
# classification accuracy on training set: 0.9382913112640381
# classification accuracy on test set: 79.0%
#
# Epoch  56
# classification accuracy on validation set: 0.8062499761581421
# classification accuracy on training set: 0.9386077523231506
# classification accuracy on test set: 80.0%
#
# Epoch  57
# classification accuracy on validation set: 0.8062499761581421
# classification accuracy on training set: 0.9395570755004883
# classification accuracy on test set: 80.0%
#
# Epoch  58
# classification accuracy on validation set: 0.8062499761581421
# classification accuracy on training set: 0.9401900172233582
# classification accuracy on test set: 80.0%
#
# Epoch  59
# classification accuracy on validation set: 0.8062499761581421
# classification accuracy on training set: 0.9411393404006958
# classification accuracy on test set: 80.0%
#
# Epoch  60
# classification accuracy on validation set: 0.824999988079071
# classification accuracy on training set: 0.9427216053009033
# classification accuracy on test set: 80.0%
#
# Epoch  61
# classification accuracy on validation set: 0.824999988079071
# classification accuracy on training set: 0.9439873099327087
# classification accuracy on test set: 80.0%
#
# Epoch  62
# classification accuracy on validation set: 0.824999988079071
# classification accuracy on training set: 0.9452531933784485
# classification accuracy on test set: 80.0%
#
# Epoch  63
# classification accuracy on validation set: 0.824999988079071
# classification accuracy on training set: 0.9462025761604309
# classification accuracy on test set: 80.0%
#
# Epoch  64
# classification accuracy on validation set: 0.831250011920929
# classification accuracy on training set: 0.9468353986740112
# classification accuracy on test set: 80.0%
#
# Epoch  65
# classification accuracy on validation set: 0.824999988079071
# classification accuracy on training set: 0.9471518397331238
# classification accuracy on test set: 81.0%
#
# Epoch  66
# classification accuracy on validation set: 0.831250011920929
# classification accuracy on training set: 0.9471518397331238
# classification accuracy on test set: 81.0%
#
# Epoch  67
# classification accuracy on validation set: 0.831250011920929
# classification accuracy on training set: 0.9471518397331238
# classification accuracy on test set: 81.0%
#
# Epoch  68
# classification accuracy on validation set: 0.831250011920929
# classification accuracy on training set: 0.9474683403968811
# classification accuracy on test set: 81.0%
#
# Epoch  69
# classification accuracy on validation set: 0.831250011920929
# classification accuracy on training set: 0.948101282119751
# classification accuracy on test set: 81.0%
#
# Epoch  70
# classification accuracy on validation set: 0.831250011920929
# classification accuracy on training set: 0.9484177231788635
# classification accuracy on test set: 79.0%
#
# Epoch  71
# classification accuracy on validation set: 0.831250011920929
# classification accuracy on training set: 0.9484177231788635
# classification accuracy on test set: 78.0%
#
# Epoch  72
# classification accuracy on validation set: 0.831250011920929
# classification accuracy on training set: 0.9487341642379761
# classification accuracy on test set: 79.0%
#
# Epoch  73
# classification accuracy on validation set: 0.8374999761581421
# classification accuracy on training set: 0.9490506052970886
# classification accuracy on test set: 79.0%
#
# Epoch  74
# classification accuracy on validation set: 0.84375
# classification accuracy on training set: 0.9490506052970886
# classification accuracy on test set: 79.0%
#
# Epoch  75
# classification accuracy on validation set: 0.84375
# classification accuracy on training set: 0.9493670463562012
# classification accuracy on test set: 80.0%
#
# Epoch  76
# classification accuracy on validation set: 0.8500000238418579
# classification accuracy on training set: 0.9493670463562012
# classification accuracy on test set: 79.0%
#
# Epoch  77
# classification accuracy on validation set: 0.8500000238418579
# classification accuracy on training set: 0.9493670463562012
# classification accuracy on test set: 78.0%
#
# Epoch  78
# classification accuracy on validation set: 0.8500000238418579
# classification accuracy on training set: 0.9493670463562012
# classification accuracy on test set: 77.0%
#
# Epoch  79
# classification accuracy on validation set: 0.8500000238418579
# classification accuracy on training set: 0.9493670463562012
# classification accuracy on test set: 76.0%
#
# Epoch  80
# classification accuracy on validation set: 0.856249988079071
# classification accuracy on training set: 0.9493670463562012
# classification accuracy on test set: 77.0%
#
# Epoch  81
# classification accuracy on validation set: 0.856249988079071
# classification accuracy on training set: 0.9493670463562012
# classification accuracy on test set: 77.0%
#
# Epoch  82
# classification accuracy on validation set: 0.856249988079071
# classification accuracy on training set: 0.9493670463562012
# classification accuracy on test set: 77.0%
#
# Epoch  83
# classification accuracy on validation set: 0.862500011920929
# classification accuracy on training set: 0.9493670463562012
# classification accuracy on test set: 77.0%
#
# Epoch  84
# classification accuracy on validation set: 0.862500011920929
# classification accuracy on training set: 0.9493670463562012
# classification accuracy on test set: 77.0%
#
# Epoch  85
# classification accuracy on validation set: 0.862500011920929
# classification accuracy on training set: 0.9493670463562012
# classification accuracy on test set: 77.0%
#
# Epoch  86
# classification accuracy on validation set: 0.862500011920929
# classification accuracy on training set: 0.9493670463562012
# classification accuracy on test set: 77.0%
#
# Epoch  87
# classification accuracy on validation set: 0.862500011920929
# classification accuracy on training set: 0.9493670463562012
# classification accuracy on test set: 77.0%
#
# Epoch  88
# classification accuracy on validation set: 0.862500011920929
# classification accuracy on training set: 0.9493670463562012
# classification accuracy on test set: 77.0%
#
# Epoch  89
# classification accuracy on validation set: 0.862500011920929
# classification accuracy on training set: 0.9493670463562012
# classification accuracy on test set: 77.0%
#
# Epoch  90
# classification accuracy on validation set: 0.862500011920929
# classification accuracy on training set: 0.9493670463562012
# classification accuracy on test set: 77.0%
#
# Epoch  91
# classification accuracy on validation set: 0.862500011920929
# classification accuracy on training set: 0.9493670463562012
# classification accuracy on test set: 77.0%
#
# Epoch  92
# classification accuracy on validation set: 0.862500011920929
# classification accuracy on training set: 0.9493670463562012
# classification accuracy on test set: 77.0%
#
# Epoch  93
# classification accuracy on validation set: 0.862500011920929
# classification accuracy on training set: 0.9493670463562012
# classification accuracy on test set: 77.0%
#
# Epoch  94
# classification accuracy on validation set: 0.862500011920929
# classification accuracy on training set: 0.9493670463562012
# classification accuracy on test set: 77.0%
#
# Epoch  95
# classification accuracy on validation set: 0.8687499761581421
# classification accuracy on training set: 0.9493670463562012
# classification accuracy on test set: 77.0%
#
# Epoch  96
# classification accuracy on validation set: 0.8687499761581421
# classification accuracy on training set: 0.9493670463562012
# classification accuracy on test set: 77.0%
#
# Epoch  97
# classification accuracy on validation set: 0.8687499761581421
# classification accuracy on training set: 0.9493670463562012
# classification accuracy on test set: 77.0%
#
# Epoch  98
# classification accuracy on validation set: 0.8687499761581421
# classification accuracy on training set: 0.9493670463562012
# classification accuracy on test set: 77.0%
#
# Epoch  99
# classification accuracy on validation set: 0.8687499761581421
# classification accuracy on training set: 0.9493670463562012
# classification accuracy on test set: 77.0%

# %%
plt.plot(val_truth)
plt.show()

# %%
plt.plot(abs(np.asarray(train_err)-np.asarray(val_err)))
plt.show()
